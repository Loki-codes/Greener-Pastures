# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# input csv
BLS_MWE_input_csv = "BLS_GEO_OCCUPATION_ALL_df_merge.csv"

#import pretty print
import pprint as pprint

#for sleep
import time

# %%
BLS_MWE_MAP = pd.read_csv(BLS_MWE_input_csv,index_col=0)
BLS_MWE_MAP
# Out:
#        GEO_city,state  year    MWE  MWE_Occupation Type_code  \
# 0     Albuquerque, NM  2019  52.28                    110000
# 1     Albuquerque, NM  2019  32.76                    130000
# 2     Albuquerque, NM  2019  22.69                    150000
# 3     Albuquerque, NM  2019  48.99                    170000
# 4     Albuquerque, NM  2019  35.44                    190000
# ...               ...   ...    ...                       ...
# 1108  Bakersfield, CA  2019  19.96                    430000
# 1109  Bakersfield, CA  2019  26.13                    470000
# 1110  Bakersfield, CA  2019  25.55                    490000
# 1111  Bakersfield, CA  2019  22.00                    510000
# 1112  Bakersfield, CA  2019  19.50                    530000
#
#                                     MWE_Occupation Type MWE_Skill Level  \
# 0                                Management occupations      All levels
# 1         Business and financial operations occupations      All levels
# ...

# %%
# Set occupation here
BLS_MWE_MAP_occ=BLS_MWE_MAP[BLS_MWE_MAP["MWE_Occupation Type_code"]==150000]
BLS_MWE_MAP_occ
# Out:
#             GEO_city,state  year    MWE  MWE_Occupation Type_code  \
# 2          Albuquerque, NM  2019  22.69                    150000
# 23             Atlanta, GA  2019  44.07                    150000
# 44              Austin, TX  2019  43.90                    150000
# 65           Baltimore, MD  2019  49.68                    150000
# 86               Boise, ID  2019  37.43                    150000
# 107          Charlotte, NC  2019  44.80                    150000
# 128            Chicago, IL  2019  44.24                    150000
# 149          Cleveland, OH  2019  38.63                    150000
# 170   Colorado Springs, CO  2019  46.67                    150000
# 191         Fort Worth, TX  2019  45.60                    150000
# 212             Denver, CO  2019  48.12                    150000
# 233            Detroit, MI  2019  41.29                    150000
# 254            El Paso, TX  2019  19.99                    150000
# ...

# %%
BLS_MWE_MAP_occ.dtypes
# Out:
# GEO_city,state               object
# year                         object
# MWE                          object
# MWE_Occupation Type_code      int64
# MWE_Occupation Type          object
# MWE_Skill Level              object
# MWE_How Paid                 object
# cityid                        int64
# cityname                     object
# stateabbrev                  object
# statename                    object
# statefips                     int64
# lat                         float64
# lon                         float64
# city_pop2019                  int64
# dtype: object

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>City</dt><dd>{GEO_city,state}</dd>
<dt>Chosen Occupation</dt><dd>{MWE_Occupation Type}</dd>
<dt>Expected Pay ($/hr)</dt><dd>{MWE}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
BLS_MWE_info = [info_box_template.format(**row) for index, row in BLS_MWE_MAP_occ.iterrows()]
locations = BLS_MWE_MAP_occ[["lat", "lon"]]

# %%
# Import API key
#from api_keys import g_key

import sys
path = "/Users/matth/Desktop"
sys.path.insert(0, path)
from API_Keys import api_key
g_key= api_key["Google Maps Platform"]

# configure gmaps with api key
gmaps.configure(api_key=g_key)

fig = gmaps.figure()

# Add marker layer
marker_layer = gmaps.marker_layer(locations, \
                                 info_box_content=[f"{info}" for info in BLS_MWE_info])

# Add layer and Display figure
fig.add_layer(marker_layer)


fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
