# %%
import pandas as pd
from IPython.display import Image, clear_output
import time

# %%
#I made a list of the heat maps we are importing.
image_list = ['../data/heatmaps/01_Feb_2020.png', '../data/Heatmaps/02_March_2020.png', '../data/Heatmaps/03_April_2020.png',\
              '../data/Heatmaps/04_May_2020.png', '../data/Heatmaps/05_June_2020.png', '../data/Heatmaps/06_July_2020.png',\
              '../data/Heatmaps/07_Aug_2020.png', '../data/Heatmaps/08_Sep_2020.png', '../data/Heatmaps/09_Oct_2020.png',\
              '../data/Heatmaps/10_Nov_2020.png', '../data/Heatmaps/11_Dec_2020.png', '../data/Heatmaps/12_Jan_2021.png',\
              '../data/Heatmaps/13_Feb_2021.png']

# %%
#this code cycles through the images at 2 second intervals and prints out the file names as it goes. 
for i in image_list:
    print(i)
    display(Image(filename=i))
    time.sleep(.8)
    clear_output(wait=True)
# Out:
# ../data/Heatmaps/13_Feb_2021.png
